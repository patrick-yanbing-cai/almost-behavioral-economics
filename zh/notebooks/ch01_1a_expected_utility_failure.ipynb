# %% [markdown]
# # 1a. 期望效用的局限
#
# > Colab 支持：即将提供。

# %% [markdown]
# ## 本节概述
#
# 简要说明本节的主问题、出发时使用的基准框架，以及读者读完后应获得的边际理解增长。这里只做概述，不展开正式课程内容。

# %% [markdown]
# ## 学习目标
#
# 列出 3-5 条学习目标，说明读者完成本节后应该能够做什么。

# %% [markdown]
# ## 预备知识
#
# 列出阅读本节前最好已经掌握的概念、数学工具、代码技能，或需要先读过的前序 notebook。保持简短，让本节仍然可以独立阅读。

# %% [markdown]
# ## 开场问题
#
# 从一个具体的困惑、选择情境、经验现象或建模问题进入本节。

# %% [markdown]
# ## 基准模型
#
# 给出本节需要的最小基准模型、参照框架或前序推理。只有在公式能帮助说明时才使用公式。

# %% [markdown]
# ## 核心张力
#
# 说明基准模型与本节要解释的现象、行为、问题或解释目标之间的差距。

# %% [markdown]
# ## 核心思路
#
# 说明本节采取的解释推进：可以是新概念、新机制、关键区分、测量思路、建模方向，或通往本章其他部分的桥。

# %% [markdown]
# ## 引导例子 / 实验
#
# 可以使用一个引导例子，也可以使用一组按顺序展开的例子或实验。形式可以是文字例子、小表格、静态数值练习、简短代码单元，或未来交互组件的占位；v0 阶段不要实现完整实验。

# %% [markdown]
# ## 理解的推进
#
# 说明本节带来的边际理解增长：读者现在能看见、区分或提出什么之前还不能处理的问题。

# %% [markdown]
# ## 本节要点
#
# 用 3-5 条简短要点收束本节。

# %% [markdown]
# ## 术语表
#
# 只列出本节实际使用的关键术语。这里给出简短定义，并链接到全站术语表维护统一表述。
#
# | 术语 | 本节中的简要含义 | 全站术语表 |
# |---|---|---|
# | 待定 | 待定 | [术语表](../docs/glossary.qmd) |

# %% [markdown]
# ## 来源地图
#
# 记录本节使用的文献来源与原创材料。来源角色使用四类：主线、支撑、延伸、原创。
#
# | 组成部分 | 来源 | 来源角色 | 在本节中的用途 |
# |---|---|---|---|
# | 主要理论主张 | 待定 | 主线 | 建立本节的核心思路 |
# | 例子或经验现象 | 待定 | 支撑 | 引出或说明核心张力 |
# | 相关延伸 | 待定 | 延伸 | 指向相关材料，但不在本节展开 |
# | 图表、代码、模拟或教学设计 | Almost Behavioral Economics 原创实现 | 原创 | 提供项目生成的教学材料 |

# %% [markdown]
# ## 参考文献
#
# 只列出本节实际引用、提到或使用的来源。不要加入本节没有用到的背景阅读。

# %% [markdown]
# ## 相关内容
#
# 链接与本节相关的 notebook、章节概览、术语表或参考资料，帮助读者定位本节。按概念关系选择链接，不按顺序机械添加。
