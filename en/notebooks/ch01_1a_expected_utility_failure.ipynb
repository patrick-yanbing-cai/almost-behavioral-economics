# %% [markdown]
# # 1a. The Failure of Expected Utility
#
# > Colab support: coming soon.

# %% [markdown]
# ## Abstract
#
# Write a short overview of the notebook's main question, the benchmark it starts from, and the marginal insight readers should gain. Keep this descriptive rather than a full lesson.

# %% [markdown]
# ## Learning Goals
#
# List 3-5 things the reader should be able to do after completing this notebook.

# %% [markdown]
# ## Prerequisites
#
# List the concepts, math, coding skills, or previous notebooks that are useful before reading this notebook. Keep this section short so the notebook remains readable on its own.

# %% [markdown]
# ## Opening Problem
#
# Start from a concrete puzzle, choice situation, empirical pattern, or modeling problem that motivates the notebook.

# %% [markdown]
# ## Baseline Model
#
# Present the minimal benchmark model, reference framework, or prior reasoning needed for the notebook. Use equations only when they clarify the argument.

# %% [markdown]
# ## Key Tension
#
# Clarify the gap between the benchmark model and the phenomenon, behavior, question, or explanatory target of this notebook.

# %% [markdown]
# ## Core Idea
#
# State the explanatory move this notebook makes: a new concept, mechanism, distinction, measurement idea, modeling direction, or bridge to another part of the chapter.

# %% [markdown]
# ## Guided Example / Experiment
#
# Use one guided example, or a sequenced set of examples or experiments when several cases are jointly necessary. The section may use prose, a small table, a static numerical exercise, a short code cell, or a future interactive widget placeholder; for v0, do not implement the full experiment.

# %% [markdown]
# ## What This Teaches Us
#
# Explain the marginal understanding gained in this notebook: what the reader can now see, distinguish, or ask that they could not before.

# %% [markdown]
# ## Key Takeaways
#
# List 3-5 concise takeaways from this notebook.

# %% [markdown]
# ## Glossary
#
# List only the key terms used in this notebook. Use short local definitions and link to the site glossary for canonical terminology.
#
# | Term | Short meaning in this notebook | Site glossary |
# |---|---|---|
# | TBD | TBD | [Glossary](../docs/glossary.qmd) |

# %% [markdown]
# ## Source Map
#
# Record the sources and original materials used in this notebook. Use one of four source roles: core, support, extension, original.
#
# | Component | Source | Source Role | Use in this notebook |
# |---|---|---|---|
# | Main theoretical claim | TBD | core | Establishes the notebook's central idea |
# | Example or empirical pattern | TBD | support | Motivates or illustrates the key tension |
# | Related extension | TBD | extension | Points to related material without expanding it here |
# | Figure, code, simulation, or teaching design | Almost Behavioral Economics original implementation | original | Provides project-generated teaching material |

# %% [markdown]
# ## References
#
# List only sources cited, mentioned, or used in this notebook. Do not include background readings that are not used in the notebook.

# %% [markdown]
# ## Related
#
# Link to related notebooks, chapter overview pages, glossary entries, or references that help place this notebook in context. Choose links by conceptual relevance, not by sequence.
