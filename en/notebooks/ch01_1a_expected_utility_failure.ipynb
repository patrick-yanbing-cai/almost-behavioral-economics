# %% [markdown]
# # 1a. The Failure of Expected Utility
#
# > Colab support: coming soon.

# %% [markdown]
# ## Abstract
#
# Beta draft placeholder: briefly preview the route from expected utility as the baseline model of risky choice to three approved diagnoses of its limits: small-stakes risk aversion, Samuelson aggregation, and Allais-style independence failures. Keep this descriptive; do not introduce reference-dependent preferences, loss aversion, probability weighting, or prospect theory here.

# %% [markdown]
# ## Learning Goals
#
# Beta draft placeholder: list 3-5 learner abilities aligned with the approved architecture.
#
# - Explain the minimal expected-utility baseline over lotteries and final wealth.
# - Identify why final-wealth curvature is an implausible explanation for ordinary small-stakes risk aversion.
# - Distinguish isolated-gamble evaluation from aggregated-sequence evaluation.
# - Explain how common consequence and common ratio comparisons pressure EU's independence structure.

# %% [markdown]
# ## Prerequisites
#
# Beta draft placeholder: keep prerequisites short so the notebook remains readable on its own.
#
# - Introductory microeconomics: utility, preferences, and marginal reasoning.
# - Probability basics: probabilities, expected value, and simple lotteries.
# - Basic calculus intuition: curvature and concavity.
# - Simple mathematical notation for payoff-probability tables.

# %% [markdown]
# ## Opening Problem
#
# Beta draft placeholder: motivate why a standard risky-choice baseline needs to be tested. The opening should name the three challenge directions without working through them: ordinary local risk attitudes, isolated versus aggregated risk evaluation, and classic lottery-choice reversals.

# %% [markdown]
# ## Baseline Model
#
# Beta draft placeholder: introduce only the minimal expected-utility benchmark needed for the later diagnoses.
#
# - Move from expected monetary value to utility-based risk evaluation.
# - Define the modern lottery representation at the level needed for 1a.
# - Present wealth curvature as the standard EU explanation of risk aversion, without turning this into a full risk-aversion theory.

# %% [markdown]
# ## Key Tension
#
# Beta draft placeholder: frame the three approved tensions against expected utility.
#
# - Final-wealth curvature versus ordinary local risk attitudes.
# - Isolated gamble evaluation versus aggregated sequence evaluation.
# - EU independence structure versus Allais common consequence and common ratio comparisons.

# %% [markdown]
# ## Core Idea
#
# Beta draft placeholder: organize the approved failures as parallel diagnoses, not as three unrelated curiosities and not as a solved model. 1a should leave the failures unresolved enough to motivate later notebooks, while avoiding any construction of reference points, loss aversion, probability weighting, or prospect theory.

# %% [markdown]
# ## Guided Example / Experiment
#
# Beta draft placeholder: use static teaching components by default. Do not implement figures, code, widgets, simulations, dashboards, or parameter sliders in this scaffold.
#
# - Rabin-style calibration example: planned static payoff and calibration tables around a small favorable 50-50 gamble, such as lose 100 / gain 110.
# - Samuelson aggregation contrast: planned static isolated-versus-aggregated distribution table around a 50-50 lose 100 / gain 200 structure.
# - Allais comparison tables: planned two-part static lottery table covering common consequence and common ratio comparisons with normalized abstract payoffs.

# %% [markdown]
# ## What This Teaches Us
#
# Beta draft placeholder: synthesize the marginal understanding from each diagnosis.
#
# - Curvature diagnosis: final-wealth curvature is too coarse for ordinary small-stakes risk aversion.
# - Evaluation-unit diagnosis: risk evaluation can depend on whether a gamble is considered in isolation or as an aggregate.
# - Independence diagnosis: Allais-style comparisons expose pressure on EU's independence structure.
# - Ending stance: expected utility remains the baseline, but risky choice needs explanations that track more than expected utility over final wealth.

# %% [markdown]
# ## Key Takeaways
#
# Beta draft placeholder: write 3-5 conclusion-style takeaways that mirror the learning goals. Do not introduce new claims here.
#
# - Expected utility is the baseline model for risky choice, not the endpoint of the chapter's explanation.
# - Final-wealth curvature cannot plausibly explain ordinary small-stakes risk aversion.
# - The unit of evaluation matters for risky choice.
# - Allais-style comparisons pressure EU's independence structure.

# %% [markdown]
# ## Glossary
#
# Beta draft placeholder: define only terms used in the notebook, with short local meanings and links to the site glossary for canonical terminology.
#
# | Term | Short meaning in this notebook | Site glossary |
# |---|---|---|
# | expected utility | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | lottery | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | final wealth | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | risk aversion | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | utility curvature | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | small-stakes risk aversion | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | aggregation | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | independence axiom | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | common consequence | TBD in beta draft | [Glossary](../docs/glossary.qmd) |
# | common ratio | TBD in beta draft | [Glossary](../docs/glossary.qmd) |

# %% [markdown]
# ## Source Map
#
# Beta draft placeholder: preserve the source map for literature sources, adapted examples, original teaching tables, and any later approved teaching design. Use one of four source roles: core, support, extension, original.
#
# | Component | Source | Source Role | Use in this notebook |
# |---|---|---|---|
# | Expected utility introduction | Bernoulli 1738; Bernoulli 1954 | core; support | Move from expected value toward utility-based risk evaluation. |
# | Modern EU baseline | von Neumann and Morgenstern 1944; Mas-Colell, Whinston, and Green 1995 | core; support | Define the expected-utility benchmark over lotteries. |
# | Wealth curvature background | Pratt 1964; Markowitz 1952; Friedman and Savage 1948 | support; support; extension | Explain the limited curvature setup without expanding into a full theory unit. |
# | Rabin calibration example | Rabin 2000; Rabin and Thaler 2001; Almost Behavioral Economics original teaching table | core; support; original | Show why final-wealth curvature cannot plausibly explain ordinary local risk attitudes. |
# | Samuelson aggregation contrast | Samuelson 1963; Almost Behavioral Economics original teaching table | core; original | Show that the unit of risk evaluation matters. |
# | Allais comparison tables | Allais 1953b; Samuelson 1952; Almost Behavioral Economics original teaching table | core; support; original | Show pressure on EU's independence structure. |

# %% [markdown]
# ## References
#
# Beta draft placeholder: list only sources cited, mentioned, or used in the learner-facing draft. Use `references/ch01_1a.bib` as the approved 1a bibliography source. New beta-stage core sources require human editor approval before being added.

# %% [markdown]
# ## Related
#
# Beta draft placeholder: link only conceptually relevant later material. A brief navigation sentence may say that the next notebook begins with reference points and gains/losses as one way the chapter moves beyond final-wealth expected utility, but do not explain 1b, 1c, 1d, probability weighting, or prospect theory inside 1a.
